# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

df = pd.read_csv('iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#selesksi fitur
x = df.iloc[:, 1:-1]
y = df.iloc[:, -1]
x.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
# plot data
# karena 4 dimensi, plot cluster spal length dan sepal width aj

plt.scatter(x.iloc[:,0], x.iloc[:,1], s=100) #s = size dot

# %%
# buat model kmeans
#coba menggunakan k=2, anggap gtw ada 3 label :3

#inisiasi
cl_kmeans = KMeans(n_clusters=2)

#fitting dan predict model
y_kmeans = cl_kmeans.fit_predict(x)

#plot hasil cluster sepal length dan sepal width
plt.scatter(x.iloc[:,0], x.iloc[:,1], s=100, c = y_kmeans)

#plot centroid
centers = cl_kmeans.cluster_centers_
plt.scatter(centers[:,0], centers[:,1], c='red', s=200, alpha=0.5)
# Out:
# c:\Users\GIO\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
#cek nilai SSE
print(f'nilai sse: {cl_kmeans.inertia_}')
# Out:
# nilai sse: 152.36870647733906

# %%
#Implementasi metode elbow

#list nilai sse
sse = []

#cari k terbaik 1-10
K = range(1, 10)

#cek nilai sse tiap K
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(x)
    sse.append(kmeanModel.inertia_)

#plot distorsi
plt.figure(figsize=(8,6))
plt.plot(K, sse, 'bx-')
plt.xlabel('K')
plt.ylabel('SSE')
plt.title('Metode Elbow utk mengetahui jumlah k terbaik')
plt.show()
# Out:
# c:\Users\GIO\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\GIO\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\GIO\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
#cek nilai sse tiap K
for index, sse_val in enumerate(sse, start=1):
    print(f'k={index}, SSE={sse_val}')
# Out:
# k=1, SSE=680.8244000000001
# k=2, SSE=152.36870647733906
# k=3, SSE=78.94084142614601
# k=4, SSE=57.440280212954754
# k=5, SSE=49.94994915514594
# k=6, SSE=45.06788684210527
# k=7, SSE=34.18920546865627
# k=8, SSE=36.37112505362505
# k=9, SSE=31.063374595353498
