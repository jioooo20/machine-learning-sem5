# %%
# %pip install opencv-python
import cv2
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: opencv-python in c:\users\gio\anaconda3\lib\site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in c:\users\gio\anaconda3\lib\site-packages (from opencv-python) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
#load

img = cv2.imread('Lenna.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) #convert
plt.imshow(img)
plt.title('gambar asli')
plt.axis('off')
plt.show()

# %%
#Resize Gambar

img_resized = cv2.resize(img, (128,128))

plt.imshow(img_resized)
plt.title('gambar setelah di-resize')
plt.axis('off')
plt.show()

# %%
#convert ke grayscale

img_gray = cv2.cvtColor(img_resized, cv2.COLOR_RGB2GRAY)
plt.imshow(img_gray, cmap='gray')
plt.title('gambar setelah di-convert ke grayscale')
plt.axis('off')
plt.show()
